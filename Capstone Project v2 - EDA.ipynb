# %% [markdown]
# # Capstone Project (real title to come later)
# ### Ryan Khaleghi and Nick Cannon

# %% [markdown]
# ## Introduction
#
#
# We

# %% [markdown]
# ## Data
#
# The dataset
#
# There are 8 ratings in the dataset: overall, value, rooms, location, cleanliness, check in/front desk, service, and business service. These are rated from 0-5 stars, with missing ratings indicated by -1.

# %%
import pandas as pd
import numpy as np
import glob
import tripadvisor_convert
import dill

#save session
dill.dump_session('notebook_env.db')

#load session
#dill.load_session('notebook_env.db')

#json_file = '/Users/Ryan/Desktop/Programming/SMU/Capstone/TripAdvisor/json_copy/73739.json'
#json_file = '/Users/Ryan/Desktop/Programming/SMU/Capstone/TripAdvisor/json/3256888.json'
#df = tripadvisor_convert.to_df(json_file)
#print(df.head(2))

# %%
from timeit import default_timer as timer #for timing

start = timer()
#load data
#path ='/Users/Ryan/Desktop/Programming/SMU/Capstone/TripAdvisor/json_copy' # use your path
path ='/Users/Ryan/Desktop/Programming/SMU/Capstone/TripAdvisor/json' # use your path
allFiles = glob.glob(path + "/*.json")
#print(allFiles)
randFiles = np.random.choice(allFiles, 500, False)
df = pd.DataFrame()
df_reviews = pd.DataFrame()
list_ = []

for file_ in randFiles:
    try:
        df = tripadvisor_convert.to_df(file_)
    except Exception:
        pass 
    list_.append(df)
    df_reviews = pd.concat(list_)
print(df_reviews.head(2))
end = timer()
print (end - start)
print(len(df_reviews))
# Out:
#                    Author AuthorLocation  \
# UR129351132  Oconnellgang             Ma
# UR129205140     naladasiy     gloucester
#
#             Business service (e.g., internet access) Check in / front desk  \
# UR129351132                                      NaN                   NaN
# UR129205140                                      NaN                   NaN
#
#             Cleanliness         Date  \
# UR129351132           5  May 4, 2012
# UR129205140           4  May 1, 2012
#
#                                                   Hotel  HotelID  \
# UR129351132  Parc Soleil by Hilton Grand Vacations Club  2515898
# UR129205140  Parc Soleil by Hilton Grand Vacations Club  2515898
#
#             HotelLocation Location Overall  PriceMax  PriceMin Rooms Service  \
# UR129351132            FL        5     5.0       179       110     5       5
# UR129205140            FL        4     5.0       179       110     4       4
#
#             Sleep Quality Value
# UR129351132             5     5
# UR129205140           NaN     5
# 552.3987062940032
# 115731

# %% [markdown]
# ### EDA
# Here we will explore the data.

# %%
df_reviews.dtypes
# Out:
# Author                                      object
# AuthorLocation                              object
# Business service (e.g., internet access)    object
# Check in / front desk                       object
# Cleanliness                                 object
# Date                                        object
# Hotel                                       object
# HotelID                                      int64
# HotelLocation                               object
# Location                                    object
# Overall                                     object
# PriceMax                                     int64
# PriceMin                                     int64
# Rooms                                       object
# Service                                     object
# Sleep Quality                               object
# Value                                       object
# dtype: object

# %%
#deal with missing numbers
df_reviews.fillna(0, inplace = True)
#df_reviews.isnull()
# Out:
#              Author  AuthorLocation  Business service (e.g., internet access)  \
# UR129351132   False           False                                     False
# UR129205140   False           False                                     False
# UR129153911   False           False                                     False
# UR129132945   False           False                                     False
# UR129118356   False           False                                     False
# UR128565793   False           False                                     False
# UR128477593   False           False                                     False
# UR128424163   False           False                                     False
# UR128245000   False           False                                     False
# UR128229287   False           False                                     False
# UR128120606   False           False                                     False
# UR128020630   False           False                                     False
# UR127775114   False           False                                     False
# UR127496226   False           False                                     False
# UR127320754   False           False                                     False
# UR127270684   False           False                                     False
# UR126749929   False           False                                     False
# UR126713004   False           False                                     False
# UR126624984   False           False                                     False
# UR126624302   False           False                                     False
# UR126338026   False           False                                     False
# UR126278180   False           False                                     False
# UR126238598   False           False                                     False
# UR126183000   False           False                                     False
# UR126083146   False           False                                     False
# UR125962875   False           False                                     False
# UR125894513   False           False                                     False
# UR125874247   False           False                                     False
# UR125791835   False           False                                     False
# UR125709223   False           False                                     False
# ...             ...             ...                                       ...
# UR4333460     False           False                                     False
# UR4123839     False           False                                     False
# UR4106862     False           False                                     False
# UR4071675     False           False                                     False
# UR4048826     False           False                                     False
# UR3933389     False           False                                     False
# UR3839626     False           False                                     False
# UR3809607     False           False                                     False
# UR3752451     False           False                                     False
# UR3689183     False           False                                     False
# UR3663591     False           False                                     False
# UR3638876     False           False                                     False
# UR3598399     False           False                                     False
# UR3493490     False           False                                     False
# UR3477500     False           False                                     False
# UR2845406     False           False                                     False
# UR2829389     False           False                                     False
# UR2822891     False           False                                     False
# UR2516156     False           False                                     False
# UR2507731     False           False                                     False
# UR2433438     False           False                                     False
# UR2294055     False           False                                     False
# UR1505420     False           False                                     False
# UR1499045     False           False                                     False
# UR1428420     False           False                                     False
# UR1421310     False           False                                     False
# UR1343930     False           False                                     False
# UR1278483     False           False                                     False
# UR1275052     False           False                                     False
# UR1154409     False           False                                     False
#
#              Check in / front desk  Cleanliness   Date  Hotel  HotelID  \
# UR129351132                  False        False  False  False    False
# UR129205140                  False        False  False  False    False
# UR129153911                  False        False  False  False    False
# UR129132945                  False        False  False  False    False
# UR129118356                  False        False  False  False    False
# UR128565793                  False        False  False  False    False
# UR128477593                  False        False  False  False    False
# UR128424163                  False        False  False  False    False
# UR128245000                  False        False  False  False    False
# UR128229287                  False        False  False  False    False
# UR128120606                  False        False  False  False    False
# UR128020630                  False        False  False  False    False
# UR127775114                  False        False  False  False    False
# UR127496226                  False        False  False  False    False
# UR127320754                  False        False  False  False    False
# UR127270684                  False        False  False  False    False
# UR126749929                  False        False  False  False    False
# UR126713004                  False        False  False  False    False
# UR126624984                  False        False  False  False    False
# UR126624302                  False        False  False  False    False
# UR126338026                  False        False  False  False    False
# UR126278180                  False        False  False  False    False
# UR126238598                  False        False  False  False    False
# UR126183000                  False        False  False  False    False
# UR126083146                  False        False  False  False    False
# UR125962875                  False        False  False  False    False
# UR125894513                  False        False  False  False    False
# UR125874247                  False        False  False  False    False
# UR125791835                  False        False  False  False    False
# UR125709223                  False        False  False  False    False
# ...                            ...          ...    ...    ...      ...
# UR4333460                    False        False  False  False    False
# UR4123839                    False        False  False  False    False
# UR4106862                    False        False  False  False    False
# UR4071675                    False        False  False  False    False
# UR4048826                    False        False  False  False    False
# UR3933389                    False        False  False  False    False
# UR3839626                    False        False  False  False    False
# UR3809607                    False        False  False  False    False
# UR3752451                    False        False  False  False    False
# UR3689183                    False        False  False  False    False
# UR3663591                    False        False  False  False    False
# UR3638876                    False        False  False  False    False
# UR3598399                    False        False  False  False    False
# UR3493490                    False        False  False  False    False
# UR3477500                    False        False  False  False    False
# UR2845406                    False        False  False  False    False
# UR2829389                    False        False  False  False    False
# UR2822891                    False        False  False  False    False
# UR2516156                    False        False  False  False    False
# UR2507731                    False        False  False  False    False
# UR2433438                    False        False  False  False    False
# UR2294055                    False        False  False  False    False
# UR1505420                    False        False  False  False    False
# UR1499045                    False        False  False  False    False
# UR1428420                    False        False  False  False    False
# UR1421310                    False        False  False  False    False
# UR1343930                    False        False  False  False    False
# UR1278483                    False        False  False  False    False
# UR1275052                    False        False  False  False    False
# UR1154409                    False        False  False  False    False
#
#              HotelLocation  Location  Overall  PriceMax  PriceMin  Rooms  \
# UR129351132          False     False    False     False     False  False
# UR129205140          False     False    False     False     False  False
# UR129153911          False     False    False     False     False  False
# UR129132945          False     False    False     False     False  False
# UR129118356          False     False    False     False     False  False
# UR128565793          False     False    False     False     False  False
# UR128477593          False     False    False     False     False  False
# UR128424163          False     False    False     False     False  False
# UR128245000          False     False    False     False     False  False
# UR128229287          False     False    False     False     False  False
# UR128120606          False     False    False     False     False  False
# UR128020630          False     False    False     False     False  False
# UR127775114          False     False    False     False     False  False
# UR127496226          False     False    False     False     False  False
# UR127320754          False     False    False     False     False  False
# UR127270684          False     False    False     False     False  False
# UR126749929          False     False    False     False     False  False
# UR126713004          False     False    False     False     False  False
# UR126624984          False     False    False     False     False  False
# UR126624302          False     False    False     False     False  False
# UR126338026          False     False    False     False     False  False
# UR126278180          False     False    False     False     False  False
# UR126238598          False     False    False     False     False  False
# UR126183000          False     False    False     False     False  False
# UR126083146          False     False    False     False     False  False
# UR125962875          False     False    False     False     False  False
# UR125894513          False     False    False     False     False  False
# UR125874247          False     False    False     False     False  False
# UR125791835          False     False    False     False     False  False
# UR125709223          False     False    False     False     False  False
# ...                    ...       ...      ...       ...       ...    ...
# UR4333460            False     False    False     False     False  False
# UR4123839            False     False    False     False     False  False
# UR4106862            False     False    False     False     False  False
# UR4071675            False     False    False     False     False  False
# UR4048826            False     False    False     False     False  False
# UR3933389            False     False    False     False     False  False
# UR3839626            False     False    False     False     False  False
# UR3809607            False     False    False     False     False  False
# UR3752451            False     False    False     False     False  False
# UR3689183            False     False    False     False     False  False
# UR3663591            False     False    False     False     False  False
# UR3638876            False     False    False     False     False  False
# UR3598399            False     False    False     False     False  False
# UR3493490            False     False    False     False     False  False
# UR3477500            False     False    False     False     False  False
# UR2845406            False     False    False     False     False  False
# UR2829389            False     False    False     False     False  False
# UR2822891            False     False    False     False     False  False
# UR2516156            False     False    False     False     False  False
# UR2507731            False     False    False     False     False  False
# UR2433438            False     False    False     False     False  False
# UR2294055            False     False    False     False     False  False
# UR1505420            False     False    False     False     False  False
# UR1499045            False     False    False     False     False  False
# UR1428420            False     False    False     False     False  False
# UR1421310            False     False    False     False     False  False
# UR1343930            False     False    False     False     False  False
# UR1278483            False     False    False     False     False  False
# UR1275052            False     False    False     False     False  False
# UR1154409            False     False    False     False     False  False
#
#              Service  Sleep Quality  Value
# UR129351132    False          False  False
# UR129205140    False          False  False
# UR129153911    False          False  False
# UR129132945    False          False  False
# UR129118356    False          False  False
# UR128565793    False          False  False
# UR128477593    False          False  False
# UR128424163    False          False  False
# UR128245000    False          False  False
# UR128229287    False          False  False
# UR128120606    False          False  False
# UR128020630    False          False  False
# UR127775114    False          False  False
# UR127496226    False          False  False
# UR127320754    False          False  False
# UR127270684    False          False  False
# UR126749929    False          False  False
# UR126713004    False          False  False
# UR126624984    False          False  False
# UR126624302    False          False  False
# UR126338026    False          False  False
# UR126278180    False          False  False
# UR126238598    False          False  False
# UR126183000    False          False  False
# UR126083146    False          False  False
# UR125962875    False          False  False
# UR125894513    False          False  False
# UR125874247    False          False  False
# UR125791835    False          False  False
# UR125709223    False          False  False
# ...              ...            ...    ...
# UR4333460      False          False  False
# UR4123839      False          False  False
# UR4106862      False          False  False
# UR4071675      False          False  False
# UR4048826      False          False  False
# UR3933389      False          False  False
# UR3839626      False          False  False
# UR3809607      False          False  False
# UR3752451      False          False  False
# UR3689183      False          False  False
# UR3663591      False          False  False
# UR3638876      False          False  False
# UR3598399      False          False  False
# UR3493490      False          False  False
# UR3477500      False          False  False
# UR2845406      False          False  False
# UR2829389      False          False  False
# UR2822891      False          False  False
# UR2516156      False          False  False
# UR2507731      False          False  False
# UR2433438      False          False  False
# UR2294055      False          False  False
# UR1505420      False          False  False
# UR1499045      False          False  False
# UR1428420      False          False  False
# UR1421310      False          False  False
# UR1343930      False          False  False
# UR1278483      False          False  False
# UR1275052      False          False  False
# UR1154409      False          False  False
#
# [115731 rows x 17 columns]

# %%
#convert ratings into numbers instead of objects
df_reviews = df_reviews.astype({'Cleanliness': 'int64', 'Location': 'int64', 'Rooms': 'int64', 'Service': 'int64', \
                   'Sleep Quality': 'int64', 'Value': 'int64', 'Business service (e.g., internet access)': 'int64', \
                  'Check in / front desk': 'int64', 'Overall': 'float'})
df_reviews.dtypes
# Out:
# Author                                       object
# AuthorLocation                               object
# Business service (e.g., internet access)      int64
# Check in / front desk                         int64
# Cleanliness                                   int64
# Date                                         object
# Hotel                                        object
# HotelID                                       int64
# HotelLocation                                object
# Location                                      int64
# Overall                                     float64
# PriceMax                                      int64
# PriceMin                                      int64
# Rooms                                         int64
# Service                                       int64
# Sleep Quality                                 int64
# Value                                         int64
# dtype: object

# %%
df_reviews.describe([.01, .05, .25, .5, .75, .95, .99])
# Out:
#        Business service (e.g., internet access)  Check in / front desk  \
# count                             115731.000000          115731.000000
# mean                                   0.370506               0.684181
# std                                    1.147981               1.559225
# min                                    0.000000               0.000000
# 1%                                     0.000000               0.000000
# 5%                                     0.000000               0.000000
# 25%                                    0.000000               0.000000
# 50%                                    0.000000               0.000000
# 75%                                    0.000000               0.000000
# 95%                                    4.000000               5.000000
# 99%                                    5.000000               5.000000
# max                                    5.000000               5.000000
#
#          Cleanliness       HotelID       Location        Overall  \
# count  115731.000000  1.157310e+05  115731.000000  115731.000000
# mean        3.637833  1.359724e+06       3.279960       3.782306
# std         1.676132  1.161742e+06       2.037583       1.262078
# min         0.000000  7.394700e+04       0.000000       1.000000
# 1%          0.000000  7.804600e+04       0.000000       1.000000
# 5%          0.000000  8.021900e+04       0.000000       1.000000
# 25%         3.000000  1.149420e+05       1.000000       3.000000
# 50%         4.000000  1.938661e+06       4.000000       4.000000
# 75%         5.000000  2.515639e+06       5.000000       5.000000
# 95%         5.000000  2.515901e+06       5.000000       5.000000
# 99%         5.000000  2.516076e+06       5.000000       5.000000
# max         5.000000  2.516243e+06       5.000000       5.000000
#
#             PriceMax       PriceMin          Rooms        Service  \
# count  115731.000000  115731.000000  115731.000000  115731.000000
# mean      320.490880     154.797842       3.063345       3.497619
# std       165.654974     127.317840       1.863729       1.700845
# min         0.000000       0.000000       0.000000       0.000000
# 1%          0.000000       0.000000       0.000000       0.000000
# 5%        130.000000      62.000000       0.000000       0.000000
# 25%       213.000000      80.000000       1.000000       3.000000
# 50%       304.000000     144.000000       4.000000       4.000000
# 75%       405.000000     200.000000       5.000000       5.000000
# 95%       579.000000     288.000000       5.000000       5.000000
# 99%       682.000000     473.000000       5.000000       5.000000
# max      5000.000000    5000.000000       5.000000       5.000000
#
#        Sleep Quality          Value
# count  115731.000000  115731.000000
# mean        2.015631       3.435631
# std         2.184533       1.670610
# min         0.000000       0.000000
# 1%          0.000000       0.000000
# 5%          0.000000       0.000000
# 25%         0.000000       3.000000
# 50%         1.000000       4.000000
# 75%         4.000000       5.000000
# 95%         5.000000       5.000000
# 99%         5.000000       5.000000
# max         5.000000       5.000000

# %%
# Remove date attribute that isn't going to be used in the analysis
df_reviews = df_reviews.drop(['Date'], axis = 1)
print(df_reviews.head(2))
# Out:
#                    Author AuthorLocation  BusServ  CheckIn  Cleanliness  \
# UR129351132  Oconnellgang             Ma        0        0            5
# UR129205140     naladasiy     gloucester        0        0            4
#
#                                                   Hotel  HotelID  \
# UR129351132  Parc Soleil by Hilton Grand Vacations Club  2515898
# UR129205140  Parc Soleil by Hilton Grand Vacations Club  2515898
#
#             HotelLocation  Location  Overall  PriceMax  PriceMin  Rooms  \
# UR129351132            FL         5      5.0       179       110      5
# UR129205140            FL         4      5.0       179       110      4
#
#              Service  Sleep Quality  Value
# UR129351132        5              5      5
# UR129205140        4              0      5

# %%
df_reviews.rename(index=str, columns={"Business service (e.g., internet access)": "BusServ", \
                                     "Check in / front desk": "CheckIn"}, inplace= True)
print(df_reviews.head(2))
# Out:
#                    Author AuthorLocation  BusServ  CheckIn  Cleanliness  \
# UR129351132  Oconnellgang             Ma        0        0            5
# UR129205140     naladasiy     gloucester        0        0            4
#
#                                                   Hotel  HotelID  \
# UR129351132  Parc Soleil by Hilton Grand Vacations Club  2515898
# UR129205140  Parc Soleil by Hilton Grand Vacations Club  2515898
#
#             HotelLocation  Location  Overall  PriceMax  PriceMin  Rooms  \
# UR129351132            FL         5      5.0       179       110      5
# UR129205140            FL         4      5.0       179       110      4
#
#              Service  Sleep Quality  Value
# UR129351132        5              5      5
# UR129205140        4              0      5

# %%
#what to do with missing values, now set to zero?
#set missing values to overall rating doesn't seem crazy, since it's the average of other ratings
#need to change from int64 to float64 because overall is a float
df_reviews = df_reviews.astype({'Cleanliness': 'float', 'Location': 'float', 'Rooms': 'float', 'Service': 'float', \
                   'Sleep Quality': 'float', 'Value': 'float', 'BusServ': 'float', 'CheckIn': 'float'})
df_reviews.dtypes
# Out:
# Author             object
# AuthorLocation     object
# BusServ           float64
# CheckIn           float64
# Cleanliness       float64
# Hotel              object
# HotelID             int64
# HotelLocation      object
# Location          float64
# Overall           float64
# PriceMax            int64
# PriceMin            int64
# Rooms             float64
# Service           float64
# Sleep Quality     float64
# Value             float64
# dtype: object

# %%
#now we can assign values
df_reviews['BusServ'] = np.where(df_reviews['BusServ'] == 0, df_reviews['Overall'], df_reviews['BusServ'])
df_reviews['CheckIn'] = np.where(df_reviews['CheckIn'] == 0, df_reviews['Overall'], df_reviews['CheckIn'])
df_reviews['Cleanliness'] = np.where(df_reviews['Cleanliness'] == 0, df_reviews['Overall'], df_reviews['Cleanliness'])
df_reviews['Location'] = np.where(df_reviews['Location'] == 0, df_reviews['Overall'], df_reviews['Location'])
df_reviews['Rooms'] = np.where(df_reviews['Rooms'] == 0, df_reviews['Overall'], df_reviews['Rooms'])
df_reviews['Service'] = np.where(df_reviews['Service'] == 0, df_reviews['Overall'], df_reviews['Service'])
df_reviews['Sleep Quality'] = np.where(df_reviews['Sleep Quality'] == 0, df_reviews['Overall'], df_reviews['Sleep Quality'])
df_reviews['Value'] = np.where(df_reviews['Value'] == 0, df_reviews['Overall'], df_reviews['Value'])
df_reviews.describe([.01, .05, .25, .5, .75, .95, .99])
# Out:
#              BusServ        CheckIn    Cleanliness       HotelID  \
# count  115731.000000  115731.000000  115731.000000  1.157310e+05
# mean        3.761576       3.813853       3.999084  1.359724e+06
# std         1.262313       1.254680       1.233164  1.161742e+06
# min         1.000000       1.000000       1.000000  7.394700e+04
# 1%          1.000000       1.000000       1.000000  7.804600e+04
# 5%          1.000000       1.000000       1.000000  8.021900e+04
# 25%         3.000000       3.000000       3.000000  1.149420e+05
# 50%         4.000000       4.000000       4.000000  1.938661e+06
# 75%         5.000000       5.000000       5.000000  2.515639e+06
# 95%         5.000000       5.000000       5.000000  2.515901e+06
# 99%         5.000000       5.000000       5.000000  2.516076e+06
# max         5.000000       5.000000       5.000000  2.516243e+06
#
#             Location        Overall       PriceMax       PriceMin  \
# count  115731.000000  115731.000000  115731.000000  115731.000000
# mean        4.174966       3.782306     320.490880     154.797842
# std         1.092578       1.262078     165.654974     127.317840
# min         1.000000       1.000000       0.000000       0.000000
# 1%          1.000000       1.000000       0.000000       0.000000
# 5%          2.000000       1.000000     130.000000      62.000000
# 25%         4.000000       3.000000     213.000000      80.000000
# 50%         5.000000       4.000000     304.000000     144.000000
# 75%         5.000000       5.000000     405.000000     200.000000
# 95%         5.000000       5.000000     579.000000     288.000000
# 99%         5.000000       5.000000     682.000000     473.000000
# max         5.000000       5.000000    5000.000000    5000.000000
#
#                Rooms        Service  Sleep Quality          Value
# count  115731.000000  115731.000000  115731.000000  115731.000000
# mean        3.766268       3.860789       3.835869       3.791638
# std         1.274797       1.296674       1.277254       1.290259
# min         1.000000       1.000000       1.000000       1.000000
# 1%          1.000000       1.000000       1.000000       1.000000
# 5%          1.000000       1.000000       1.000000       1.000000
# 25%         3.000000       3.000000       3.000000       3.000000
# 50%         4.000000       4.000000       4.000000       4.000000
# 75%         5.000000       5.000000       5.000000       5.000000
# 95%         5.000000       5.000000       5.000000       5.000000
# 99%         5.000000       5.000000       5.000000       5.000000
# max         5.000000       5.000000       5.000000       5.000000

# %%
import matplotlib.pyplot as plt
df_reviews.boxplot(column=['Overall', 'BusServ', 'CheckIn', 'Cleanliness', 'Location', 'Rooms', 'Service', \
                           'Sleep Quality', 'Value'])
plt.show()
